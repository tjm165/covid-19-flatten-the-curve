# %%
import requests

# %%
url = 'http://covid-hotline-bling.herokuapp.com/dataallfips/raw'  
request = requests.get(url = url) 
deaths = request.json()

# %%
for death in deaths:
    print(death)
# Out:
# ', 'cases': 1, 'deaths': 0}
# {'date': '2020-04-01', 'county': 'King and Queen', 'state': 'Virginia', 'fips': '51097', 'cases': 1, 'deaths': 0}
# {'date': '2020-04-01', 'county': 'Lancaster', 'state': 'Virginia', 'fips': '51103', 'cases': 1, 'deaths': 0}
# {'date': '2020-04-01', 'county': 'Lee', 'state': 'Virginia', 'fips': '51105', 'cases': 2, 'deaths': 0}
# {'date': '2020-04-01', 'county': 'Loudoun', 'state': 'Virginia', 'fips': '51107', 'cases': 105, 'deaths': 0}
# {'date': '2020-04-01', 'county': 'Louisa', 'state': 'Virginia', 'fips': '51109', 'cases': 11, 'deaths': 0}
# {'date': '2020-04-01', 'county': 'Lynchburg city', 'state': 'Virginia', 'fips': '51680', 'cases': 7, 'deaths': 0}
# {'date': '2020-04-01', 'county': 'Madison', 'state': 'Virginia', 'fips': '51113', 'cases': 3, 'deaths': 0}
# {'date': '2020-04-01', 'county': 'Manassas Park city', 'state': 'Virginia', 'fips': '51685', 'cases': 1, 'deaths': 0}
# ...
